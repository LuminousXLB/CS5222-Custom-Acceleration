# %%
import struct
import time
from pathlib import Path

from matplotlib import pyplot as plt
from torchvision import transforms
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
def load_label(filename):
    with open(filename, "rb") as flbl:
        magic, num = struct.unpack(">II", flbl.read(8))
        return np.fromfile(flbl, dtype=np.int8)


def load_data(filename):
    with open(filename, "rb") as fimg:
        magic, num, rows, cols = struct.unpack(">IIII", fimg.read(16))
        return np.fromfile(fimg, dtype=np.uint8).reshape(num, rows, cols)


BASE = Path("../mnist")

train_images = torch.tensor(load_data(BASE / "train-images-idx3-ubyte")).long()
train_labels = torch.tensor(load_label(BASE / "train-labels-idx1-ubyte")).long()
test_images = torch.tensor(load_data(BASE / "t10k-images-idx3-ubyte")).long()
test_labels = torch.tensor(load_label(BASE / "t10k-labels-idx1-ubyte")).long()

print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([60000])
# torch.Size([10000, 28, 28])
# torch.Size([10000])

# %%
class MLP(nn.Module):
    def __init__(self, input_size, output_size=10):
        super().__init__()
        self.layer1 = nn.Linear(input_size, 16, bias=False)
        self.layer2 = nn.Linear(16, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = torch.relu(x)
        x = self.layer2(x)
        return F.log_softmax(x, dim=1)

# %%
def normalize_input(images, size, depth):
    R = transforms.Resize((size, size))
    images = R(images).long()
    images = torch.flatten(images, start_dim=1)
    return images >> (8 - depth)

# %%
BATCH_SIZE = 200
INPUT_SIZE = 8
INPUT_DEPTH = 4
INPUT_COUNT = train_labels.shape[0]

train_inputs = normalize_input(train_images, INPUT_SIZE, INPUT_DEPTH)
test_inputs = normalize_input(test_images, INPUT_SIZE, INPUT_DEPTH)
train_output = F.one_hot(train_labels, num_classes=10)

net = MLP(INPUT_SIZE**2)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)


start = time.time()
for epoch in range(128):
    running_loss = 0
    num_batches = 0
    shuffled_indices = torch.randperm(INPUT_COUNT)
    for count in range(0, INPUT_COUNT, BATCH_SIZE):
        indices = shuffled_indices[count : count + BATCH_SIZE]

        batch_inputs = train_inputs[indices]
        batch_output = train_output[indices]

        # forward and backward pass
        optimizer.zero_grad()
        loss = criterion(net(batch_inputs.float()), batch_output.float())
        loss.backward()
        optimizer.step()

        # compute some stats
        running_loss += loss.detach().item()
        num_batches += 1

        total_loss = running_loss / num_batches
        elapsed_time = time.time() - start

        if num_batches % 100 == 0:
            # scheduler.step()
            with torch.no_grad():
                outputs = net(test_inputs.float())
                correct = sum(outputs.argmax(dim=1) == test_labels).item()

            print(
                {
                    "epoch": epoch,
                    "batches": num_batches,
                    "elapsed_time": round(elapsed_time, 2),
                    "total_loss": total_loss,
                    "accuracy": round(correct / len(test_inputs) * 100, 2),
                }
            )
# Out:
# {'epoch': 0, 'batches': 100, 'elapsed_time': 0.64, 'total_loss': 1.9085989308357239, 'accuracy': 56.22}
# {'epoch': 0, 'batches': 200, 'elapsed_time': 1.3, 'total_loss': 1.5223220992088318, 'accuracy': 70.95}
# {'epoch': 0, 'batches': 300, 'elapsed_time': 1.81, 'total_loss': 1.3065451590220134, 'accuracy': 75.68}
# {'epoch': 1, 'batches': 100, 'elapsed_time': 2.19, 'total_loss': 0.7591801536083221, 'accuracy': 77.94}
# {'epoch': 1, 'batches': 200, 'elapsed_time': 2.76, 'total_loss': 0.7357501867413521, 'accuracy': 79.17}
# {'epoch': 1, 'batches': 300, 'elapsed_time': 3.3, 'total_loss': 0.71244293709596, 'accuracy': 80.33}
# {'epoch': 2, 'batches': 100, 'elapsed_time': 3.92, 'total_loss': 0.6396797794103622, 'accuracy': 80.95}
# {'epoch': 2, 'batches': 200, 'elapsed_time': 4.67, 'total_loss': 0.6298622503876686, 'accuracy': 81.63}
# {'epoch': 2, 'batches': 300, 'elapsed_time': 5.11, 'total_loss': 0.6249014707406362, 'accuracy': 82.12}
# {'epoch': 3, 'batches': 100, 'elapsed_time': 5.67, 'total_loss': 0.5965874025225639, 'accuracy': 82.37}
# {'epoch': 3, 'batches': 200, 'elapsed_time': 6.02, 'total_loss': 0.5888220308721066, 'accuracy': 82.87}
# {'epoch': 3, 'batches': 300, 'elapsed_time': 6.46, 'total_loss': 0.5846199155847231, 'accuracy': 82.82}
# {'epoch': 4, 'batches': 100, 'elapsed_time': 7.01, 'total_loss': 0.572968832552433, 'accuracy': 83.45}
# {'epoch': 4, 'batches': 200, 'elapsed_time': 7.45, 'total_loss': 0.5614348694682121, 'accuracy': 83.6}
# {'epoch': 4, 'batches': 300, 'elapsed_time': 7.94, 'total_loss': 0.5604654962817828, 'accuracy': 83.39}
# {'epoch': 5, 'batches': 100, 'elapsed_time': 8.36, 'total_loss': 0.5467122507095337, 'accuracy': 83.66}
# {'epoch': 5, 'batches': 200, 'elapsed_time': 8.64, 'total_loss': 0.5450916962325573, 'accuracy': 84.0}
# {'epoch': 5, 'batches': 300, 'elapsed_time': 8.91, 'total_loss': 0.543973997036616, 'accuracy': 84.32}
# {'epoch': 6, 'batches': 100, 'elapsed_time': 9.44, 'total_loss': 0.5402221351861953, 'accuracy': 84.48}
# {'epoch': 6, 'batches': 200, 'elapsed_time': 9.79, 'total_loss': 0.53417829439044, 'accuracy': 84.49}
# {'epoch': 6, 'batches': 300, 'elapsed_time': 10.13, 'total_loss': 0.5313323600093524, 'accuracy': 84.73}
# {'epoch': 7, 'batches': 100, 'elapsed_time': 10.49, 'total_loss': 0.5264129167795182, 'accuracy': 84.84}
# {'epoch': 7, 'batches': 200, 'elapsed_time': 11.04, 'total_loss': 0.5268791811168194, 'accuracy': 84.61}
# {'epoch': 7, 'batches': 300, 'elapsed_time': 11.64, 'total_loss': 0.5214564939339955, 'accuracy': 85.0}
# {'epoch': 8, 'batches': 100, 'elapsed_time': 12.19, 'total_loss': 0.5042209157347679, 'accuracy': 85.08}
# {'epoch': 8, 'batches': 200, 'elapsed_time': 12.77, 'total_loss': 0.5125081227719783, 'accuracy': 85.03}
# {'epoch': 8, 'batches': 300, 'elapsed_time': 13.36, 'total_loss': 0.5120161304871241, 'accuracy': 85.01}
# {'epoch': 9, 'batches': 100, 'elapsed_time': 13.9, 'total_loss': 0.5015100562572479, 'accuracy': 85.07}
# {'epoch': 9, 'batches': 200, 'elapsed_time': 14.65, 'total_loss': 0.5032592923939228, 'accuracy': 85.17}
# {'epoch': 9, 'batches': 300, 'elapsed_time': 15.28, 'total_loss': 0.5034648702541987, 'accuracy': 85.32}
# {'epoch': 10, 'batches': 100, 'elapsed_time': 16.05, 'total_loss': 0.4940665900707245, 'accuracy': 85.36}
# {'epoch': 10, 'batches': 200, 'elapsed_time': 16.62, 'total_loss': 0.49653268948197365, 'accuracy': 85.1}
# {'epoch': 10, 'batches': 300, 'elapsed_time': 17.25, 'total_loss': 0.4963143207629522, 'accuracy': 85.29}
# {'epoch': 11, 'batches': 100, 'elapsed_time': 17.84, 'total_loss': 0.5015014213323593, 'accuracy': 85.19}
# {'epoch': 11, 'batches': 200, 'elapsed_time': 18.58, 'total_loss': 0.49470166936516763, 'accuracy': 85.23}
# {'epoch': 11, 'batches': 300, 'elapsed_time': 19.11, 'total_loss': 0.48891321460405984, 'accuracy': 85.44}
# {'epoch': 12, 'batches': 100, 'elapsed_time': 19.68, 'total_loss': 0.4759963607788086, 'accuracy': 85.34}
# {'epoch': 12, 'batches': 200, 'elapsed_time': 20.25, 'total_loss': 0.4783779275417328, 'accuracy': 85.65}
# {'epoch': 12, 'batches': 300, 'elapsed_time': 20.82, 'total_loss': 0.4821269571781158, 'accuracy': 85.6}
# {'epoch': 13, 'batches': 100, 'elapsed_time': 21.62, 'total_loss': 0.470929728448391, 'accuracy': 85.65}
# {'epoch': 13, 'batches': 200, 'elapsed_time': 22.11, 'total_loss': 0.47653031289577485, 'accuracy': 85.59}
# {'epoch': 13, 'batches': 300, 'elapsed_time': 22.64, 'total_loss': 0.4754829207062721, 'accuracy': 85.77}
# {'epoch': 14, 'batches': 100, 'elapsed_time': 23.09, 'total_loss': 0.4813282549381256, 'accuracy': 85.73}
# {'epoch': 14, 'batches': 200, 'elapsed_time': 23.6, 'total_loss': 0.4743825703859329, 'accuracy': 85.8}
# {'epoch': 14, 'batches': 300, 'elapsed_time': 24.21, 'total_loss': 0.46905420829852423, 'accuracy': 85.89}
# {'epoch': 15, 'batches': 100, 'elapsed_time': 24.74, 'total_loss': 0.45811185777187347, 'accuracy': 85.98}
# {'epoch': 15, 'batches': 200, 'elapsed_time': 25.13, 'total_loss': 0.45792761236429214, 'accuracy': 86.03}
# {'epoch': 15, 'batches': 300, 'elapsed_time': 25.59, 'total_loss': 0.46264990339676537, 'accuracy': 86.31}
# {'epoch': 16, 'batches': 100, 'elapsed_time': 26.07, 'total_loss': 0.45542306572198865, 'accuracy': 85.97}
# {'epoch': 16, 'batches': 200, 'elapsed_time': 26.48, 'total_loss': 0.45671083018183706, 'accuracy': 86.15}
# {'epoch': 16, 'batches': 300, 'elapsed_time': 27.37, 'total_loss': 0.45666486452023186, 'accuracy': 86.12}
# {'epoch': 17, 'batches': 100, 'elapsed_time': 27.99, 'total_loss': 0.4430014473199844, 'accuracy': 86.1}
# {'epoch': 17, 'batches': 200, 'elapsed_time': 28.5, 'total_loss': 0.4506957545876503, 'accuracy': 86.6}
# {'epoch': 17, 'batches': 300, 'elapsed_time': 29.01, 'total_loss': 0.4512442518273989, 'accuracy': 86.44}
# {'epoch': 18, 'batches': 100, 'elapsed_time': 29.41, 'total_loss': 0.4491176888346672, 'accuracy': 86.62}
# {'epoch': 18, 'batches': 200, 'elapsed_time': 29.8, 'total_loss': 0.4485845509171486, 'accuracy': 86.61}
# {'epoch': 18, 'batches': 300, 'elapsed_time': 30.31, 'total_loss': 0.4453690218925476, 'accuracy': 86.75}
# {'epoch': 19, 'batches': 100, 'elapsed_time': 30.72, 'total_loss': 0.4461767464876175, 'accuracy': 86.54}
# {'epoch': 19, 'batches': 200, 'elapsed_time': 31.19, 'total_loss': 0.4422943276166916, 'accuracy': 86.67}
# {'epoch': 19, 'batches': 300, 'elapsed_time': 31.93, 'total_loss': 0.4405021717151006, 'accuracy': 86.96}
# {'epoch': 20, 'batches': 100, 'elapsed_time': 32.39, 'total_loss': 0.42750192746520044, 'accuracy': 86.91}
# {'epoch': 20, 'batches': 200, 'elapsed_time': 32.83, 'total_loss': 0.43111316807568073, 'accuracy': 86.81}
# {'epoch': 20, 'batches': 300, 'elapsed_time': 33.25, 'total_loss': 0.4354481035967668, 'accuracy': 86.83}
# {'epoch': 21, 'batches': 100, 'elapsed_time': 33.8, 'total_loss': 0.4294856110215187, 'accuracy': 87.01}
# {'epoch': 21, 'batches': 200, 'elapsed_time': 34.31, 'total_loss': 0.4314447945356369, 'accuracy': 86.99}
# {'epoch': 21, 'batches': 300, 'elapsed_time': 34.94, 'total_loss': 0.4314742815494537, 'accuracy': 87.06}
# {'epoch': 22, 'batches': 100, 'elapsed_time': 35.55, 'total_loss': 0.42177328675985337, 'accuracy': 86.92}
# {'epoch': 22, 'batches': 200, 'elapsed_time': 36.15, 'total_loss': 0.42895465053617954, 'accuracy': 87.28}
# {'epoch': 22, 'batches': 300, 'elapsed_time': 36.68, 'total_loss': 0.42814204573631287, 'accuracy': 87.37}
# {'epoch': 23, 'batches': 100, 'elapsed_time': 37.42, 'total_loss': 0.42710603967308997, 'accuracy': 87.03}
# {'epoch': 23, 'batches': 200, 'elapsed_time': 37.94, 'total_loss': 0.4267491804808378, 'accuracy': 87.26}
# {'epoch': 23, 'batches': 300, 'elapsed_time': 38.47, 'total_loss': 0.42463211983442306, 'accuracy': 87.34}
# {'epoch': 24, 'batches': 100, 'elapsed_time': 39.16, 'total_loss': 0.41498455971479414, 'accuracy': 87.27}
# {'epoch': 24, 'batches': 200, 'elapsed_time': 39.77, 'total_loss': 0.41941228285431864, 'accuracy': 87.29}
# {'epoch': 24, 'batches': 300, 'elapsed_time': 40.4, 'total_loss': 0.4201925182342529, 'accuracy': 87.38}
# {'epoch': 25, 'batches': 100, 'elapsed_time': 41.08, 'total_loss': 0.4070383730530739, 'accuracy': 87.31}
# {'epoch': 25, 'batches': 200, 'elapsed_time': 41.64, 'total_loss': 0.4162049416452646, 'accuracy': 87.38}
# {'epoch': 25, 'batches': 300, 'elapsed_time': 41.92, 'total_loss': 0.41706946536898615, 'accuracy': 87.56}
# {'epoch': 26, 'batches': 100, 'elapsed_time': 42.32, 'total_loss': 0.41803535997867586, 'accuracy': 87.44}
# {'epoch': 26, 'batches': 200, 'elapsed_time': 42.62, 'total_loss': 0.4162447229027748, 'accuracy': 87.48}
# {'epoch': 26, 'batches': 300, 'elapsed_time': 42.9, 'total_loss': 0.4133054951826731, 'accuracy': 87.54}
# {'epoch': 27, 'batches': 100, 'elapsed_time': 43.38, 'total_loss': 0.3976790775358677, 'accuracy': 87.55}
# {'epoch': 27, 'batches': 200, 'elapsed_time': 43.73, 'total_loss': 0.40485405914485456, 'accuracy': 87.66}
# {'epoch': 27, 'batches': 300, 'elapsed_time': 44.15, 'total_loss': 0.41038058246175446, 'accuracy': 87.57}
# {'epoch': 28, 'batches': 100, 'elapsed_time': 44.57, 'total_loss': 0.4085071349143982, 'accuracy': 87.58}
# {'epoch': 28, 'batches': 200, 'elapsed_time': 45.0, 'total_loss': 0.40775607511401174, 'accuracy': 87.68}
# {'epoch': 28, 'batches': 300, 'elapsed_time': 45.66, 'total_loss': 0.40628301312526066, 'accuracy': 87.58}
# {'epoch': 29, 'batches': 100, 'elapsed_time': 46.26, 'total_loss': 0.40449086517095567, 'accuracy': 87.65}
# {'epoch': 29, 'batches': 200, 'elapsed_time': 46.87, 'total_loss': 0.40493547797203067, 'accuracy': 87.7}
# {'epoch': 29, 'batches': 300, 'elapsed_time': 47.35, 'total_loss': 0.4027616889278094, 'accuracy': 87.78}
# {'epoch': 30, 'batches': 100, 'elapsed_time': 47.67, 'total_loss': 0.4064854677021503, 'accuracy': 87.64}
# {'epoch': 30, 'batches': 200, 'elapsed_time': 48.08, 'total_loss': 0.3981643697619438, 'accuracy': 87.95}
# {'epoch': 30, 'batches': 300, 'elapsed_time': 48.59, 'total_loss': 0.3997946798304717, 'accuracy': 87.86}
# {'epoch': 31, 'batches': 100, 'elapsed_time': 49.21, 'total_loss': 0.3935615226626396, 'accuracy': 87.81}
# {'epoch': 31, 'batches': 200, 'elapsed_time': 49.77, 'total_loss': 0.3963958179950714, 'accuracy': 87.92}
# {'epoch': 31, 'batches': 300, 'elapsed_time': 50.2, 'total_loss': 0.3964001716176669, 'accuracy': 87.97}
# {'epoch': 32, 'batches': 100, 'elapsed_time': 50.54, 'total_loss': 0.40004175320267676, 'accuracy': 88.02}
# {'epoch': 32, 'batches': 200, 'elapsed_time': 50.83, 'total_loss': 0.39568778827786444, 'accuracy': 88.02}
# {'epoch': 32, 'batches': 300, 'elapsed_time': 51.11, 'total_loss': 0.39331404904524486, 'accuracy': 87.99}
# {'epoch': 33, 'batches': 100, 'elapsed_time': 51.48, 'total_loss': 0.4002252596616745, 'accuracy': 88.11}
# {'epoch': 33, 'batches': 200, 'elapsed_time': 51.78, 'total_loss': 0.39107019275426863, 'accuracy': 88.19}
# {'epoch': 33, 'batches': 300, 'elapsed_time': 52.06, 'total_loss': 0.3909808920820554, 'accuracy': 88.12}
# {'epoch': 34, 'batches': 100, 'elapsed_time': 52.52, 'total_loss': 0.3918403533101082, 'accuracy': 88.16}
# {'epoch': 34, 'batches': 200, 'elapsed_time': 53.06, 'total_loss': 0.3932684891670942, 'accuracy': 88.2}
# {'epoch': 34, 'batches': 300, 'elapsed_time': 53.58, 'total_loss': 0.3880192918082078, 'accuracy': 88.15}
# {'epoch': 35, 'batches': 100, 'elapsed_time': 54.1, 'total_loss': 0.38697022944688797, 'accuracy': 88.13}
# {'epoch': 35, 'batches': 200, 'elapsed_time': 54.61, 'total_loss': 0.38751591354608533, 'accuracy': 88.32}
# {'epoch': 35, 'batches': 300, 'elapsed_time': 54.91, 'total_loss': 0.38552679255604744, 'accuracy': 88.29}
# {'epoch': 36, 'batches': 100, 'elapsed_time': 55.22, 'total_loss': 0.38148997008800506, 'accuracy': 88.31}
# {'epoch': 36, 'batches': 200, 'elapsed_time': 55.58, 'total_loss': 0.38095552012324335, 'accuracy': 88.35}
# {'epoch': 36, 'batches': 300, 'elapsed_time': 55.9, 'total_loss': 0.38314773857593537, 'accuracy': 88.24}
# {'epoch': 37, 'batches': 100, 'elapsed_time': 56.42, 'total_loss': 0.38842677414417265, 'accuracy': 88.4}
# {'epoch': 37, 'batches': 200, 'elapsed_time': 56.82, 'total_loss': 0.3846325697004795, 'accuracy': 88.3}
# {'epoch': 37, 'batches': 300, 'elapsed_time': 57.26, 'total_loss': 0.38128084619839986, 'accuracy': 88.47}
# {'epoch': 38, 'batches': 100, 'elapsed_time': 57.57, 'total_loss': 0.3719682839512825, 'accuracy': 88.41}
# {'epoch': 38, 'batches': 200, 'elapsed_time': 57.88, 'total_loss': 0.3787990836799145, 'accuracy': 88.47}
# {'epoch': 38, 'batches': 300, 'elapsed_time': 58.23, 'total_loss': 0.37907229507962864, 'accuracy': 88.25}
# {'epoch': 39, 'batches': 100, 'elapsed_time': 58.53, 'total_loss': 0.38562766820192335, 'accuracy': 88.36}
# {'epoch': 39, 'batches': 200, 'elapsed_time': 58.92, 'total_loss': 0.37940890818834305, 'accuracy': 88.39}
# {'epoch': 39, 'batches': 300, 'elapsed_time': 59.56, 'total_loss': 0.37709676533937453, 'accuracy': 88.53}
# {'epoch': 40, 'batches': 100, 'elapsed_time': 60.16, 'total_loss': 0.3675562058389187, 'accuracy': 88.66}
# {'epoch': 40, 'batches': 200, 'elapsed_time': 60.72, 'total_loss': 0.3683305536955595, 'accuracy': 88.66}
# {'epoch': 40, 'batches': 300, 'elapsed_time': 61.35, 'total_loss': 0.37513758420944215, 'accuracy': 88.68}
# {'epoch': 41, 'batches': 100, 'elapsed_time': 61.78, 'total_loss': 0.3805215661227703, 'accuracy': 88.45}
# {'epoch': 41, 'batches': 200, 'elapsed_time': 62.16, 'total_loss': 0.36987029448151587, 'accuracy': 88.84}
# {'epoch': 41, 'batches': 300, 'elapsed_time': 62.63, 'total_loss': 0.3730971527099609, 'accuracy': 88.55}
# {'epoch': 42, 'batches': 100, 'elapsed_time': 63.03, 'total_loss': 0.36863560482859614, 'accuracy': 88.69}
# {'epoch': 42, 'batches': 200, 'elapsed_time': 63.53, 'total_loss': 0.36971091128885747, 'accuracy': 88.58}
# {'epoch': 42, 'batches': 300, 'elapsed_time': 63.86, 'total_loss': 0.37152048796415327, 'accuracy': 88.74}
# {'epoch': 43, 'batches': 100, 'elapsed_time': 64.25, 'total_loss': 0.36955475524067877, 'accuracy': 88.62}
# {'epoch': 43, 'batches': 200, 'elapsed_time': 64.77, 'total_loss': 0.3672671822458506, 'accuracy': 88.69}
# {'epoch': 43, 'batches': 300, 'elapsed_time': 65.21, 'total_loss': 0.3695936186114947, 'accuracy': 88.89}
# {'epoch': 44, 'batches': 100, 'elapsed_time': 65.95, 'total_loss': 0.3651548735797405, 'accuracy': 88.71}
# {'epoch': 44, 'batches': 200, 'elapsed_time': 66.52, 'total_loss': 0.3695798871666193, 'accuracy': 88.83}
# {'epoch': 44, 'batches': 300, 'elapsed_time': 67.18, 'total_loss': 0.3683702324827512, 'accuracy': 88.66}
# {'epoch': 45, 'batches': 100, 'elapsed_time': 67.61, 'total_loss': 0.36865541130304336, 'accuracy': 88.85}
# {'epoch': 45, 'batches': 200, 'elapsed_time': 68.07, 'total_loss': 0.3662535671144724, 'accuracy': 88.86}
# {'epoch': 45, 'batches': 300, 'elapsed_time': 68.54, 'total_loss': 0.3664876414835453, 'accuracy': 88.83}
# {'epoch': 46, 'batches': 100, 'elapsed_time': 68.95, 'total_loss': 0.36476903542876243, 'accuracy': 88.71}
# {'epoch': 46, 'batches': 200, 'elapsed_time': 69.32, 'total_loss': 0.36447411753237247, 'accuracy': 88.86}
# {'epoch': 46, 'batches': 300, 'elapsed_time': 69.91, 'total_loss': 0.36520868306358656, 'accuracy': 88.76}
# {'epoch': 47, 'batches': 100, 'elapsed_time': 70.54, 'total_loss': 0.35781331449747084, 'accuracy': 88.93}
# {'epoch': 47, 'batches': 200, 'elapsed_time': 71.09, 'total_loss': 0.3598243845999241, 'accuracy': 88.88}
# {'epoch': 47, 'batches': 300, 'elapsed_time': 71.55, 'total_loss': 0.36388845001657805, 'accuracy': 88.85}
# {'epoch': 48, 'batches': 100, 'elapsed_time': 72.1, 'total_loss': 0.365876831561327, 'accuracy': 88.95}
# {'epoch': 48, 'batches': 200, 'elapsed_time': 72.51, 'total_loss': 0.36127661883831025, 'accuracy': 88.74}
# {'epoch': 48, 'batches': 300, 'elapsed_time': 72.98, 'total_loss': 0.36276846637328464, 'accuracy': 88.91}
# {'epoch': 49, 'batches': 100, 'elapsed_time': 73.85, 'total_loss': 0.3540249924361706, 'accuracy': 88.88}
# {'epoch': 49, 'batches': 200, 'elapsed_time': 74.67, 'total_loss': 0.3567728827893734, 'accuracy': 88.82}
# {'epoch': 49, 'batches': 300, 'elapsed_time': 75.29, 'total_loss': 0.36124285966157915, 'accuracy': 88.96}
# {'epoch': 50, 'batches': 100, 'elapsed_time': 75.77, 'total_loss': 0.35373382300138473, 'accuracy': 89.05}
# {'epoch': 50, 'batches': 200, 'elapsed_time': 76.18, 'total_loss': 0.35878063172101976, 'accuracy': 88.93}
# {'epoch': 50, 'batches': 300, 'elapsed_time': 76.63, 'total_loss': 0.3606481195986271, 'accuracy': 88.85}
# {'epoch': 51, 'batches': 100, 'elapsed_time': 76.99, 'total_loss': 0.3623178365826607, 'accuracy': 88.87}
# {'epoch': 51, 'batches': 200, 'elapsed_time': 77.57, 'total_loss': 0.36293111376464365, 'accuracy': 88.97}
# {'epoch': 51, 'batches': 300, 'elapsed_time': 78.17, 'total_loss': 0.3593422497312228, 'accuracy': 89.07}
# {'epoch': 52, 'batches': 100, 'elapsed_time': 78.75, 'total_loss': 0.3623254844546318, 'accuracy': 88.92}
# {'epoch': 52, 'batches': 200, 'elapsed_time': 79.22, 'total_loss': 0.359044189453125, 'accuracy': 89.07}
# {'epoch': 52, 'batches': 300, 'elapsed_time': 79.78, 'total_loss': 0.3583626357714335, 'accuracy': 88.85}
# {'epoch': 53, 'batches': 100, 'elapsed_time': 80.36, 'total_loss': 0.3619295382499695, 'accuracy': 89.07}
# {'epoch': 53, 'batches': 200, 'elapsed_time': 80.99, 'total_loss': 0.3617829440534115, 'accuracy': 89.02}
# {'epoch': 53, 'batches': 300, 'elapsed_time': 81.54, 'total_loss': 0.3576943592727184, 'accuracy': 89.17}
# {'epoch': 54, 'batches': 100, 'elapsed_time': 82.17, 'total_loss': 0.35059368222951887, 'accuracy': 89.04}
# {'epoch': 54, 'batches': 200, 'elapsed_time': 82.71, 'total_loss': 0.35541079722344876, 'accuracy': 89.07}
# {'epoch': 54, 'batches': 300, 'elapsed_time': 83.24, 'total_loss': 0.3559321177502473, 'accuracy': 88.95}
# {'epoch': 55, 'batches': 100, 'elapsed_time': 83.81, 'total_loss': 0.3636526741087437, 'accuracy': 89.2}
# {'epoch': 55, 'batches': 200, 'elapsed_time': 84.25, 'total_loss': 0.3571380356699228, 'accuracy': 89.19}
# {'epoch': 55, 'batches': 300, 'elapsed_time': 84.7, 'total_loss': 0.3549805299937725, 'accuracy': 89.0}
# {'epoch': 56, 'batches': 100, 'elapsed_time': 85.43, 'total_loss': 0.3535413782298565, 'accuracy': 89.11}
# {'epoch': 56, 'batches': 200, 'elapsed_time': 85.97, 'total_loss': 0.35443658359348773, 'accuracy': 89.13}
# {'epoch': 56, 'batches': 300, 'elapsed_time': 86.47, 'total_loss': 0.35417695199449856, 'accuracy': 88.94}
# {'epoch': 57, 'batches': 100, 'elapsed_time': 87.01, 'total_loss': 0.3562142750620842, 'accuracy': 89.22}
# {'epoch': 57, 'batches': 200, 'elapsed_time': 87.46, 'total_loss': 0.34835684232413766, 'accuracy': 89.03}
# {'epoch': 57, 'batches': 300, 'elapsed_time': 87.92, 'total_loss': 0.35344110305110615, 'accuracy': 89.08}
# {'epoch': 58, 'batches': 100, 'elapsed_time': 88.41, 'total_loss': 0.34719335198402407, 'accuracy': 89.17}
# {'epoch': 58, 'batches': 200, 'elapsed_time': 88.8, 'total_loss': 0.351182869002223, 'accuracy': 89.13}
# {'epoch': 58, 'batches': 300, 'elapsed_time': 89.28, 'total_loss': 0.35274322792887686, 'accuracy': 89.09}
# {'epoch': 59, 'batches': 100, 'elapsed_time': 89.94, 'total_loss': 0.33897500187158586, 'accuracy': 89.12}
# {'epoch': 59, 'batches': 200, 'elapsed_time': 90.32, 'total_loss': 0.3474334014952183, 'accuracy': 89.02}
# {'epoch': 59, 'batches': 300, 'elapsed_time': 90.92, 'total_loss': 0.3514055920143922, 'accuracy': 88.96}
# {'epoch': 60, 'batches': 100, 'elapsed_time': 91.33, 'total_loss': 0.3414650049805641, 'accuracy': 89.18}
# {'epoch': 60, 'batches': 200, 'elapsed_time': 91.74, 'total_loss': 0.34819499276578425, 'accuracy': 89.16}
# {'epoch': 60, 'batches': 300, 'elapsed_time': 92.14, 'total_loss': 0.350473414460818, 'accuracy': 89.17}
# {'epoch': 61, 'batches': 100, 'elapsed_time': 92.69, 'total_loss': 0.3465601623058319, 'accuracy': 89.25}
# {'epoch': 61, 'batches': 200, 'elapsed_time': 93.12, 'total_loss': 0.350986921787262, 'accuracy': 89.1}
# {'epoch': 61, 'batches': 300, 'elapsed_time': 93.6, 'total_loss': 0.34999028508861857, 'accuracy': 89.26}
# {'epoch': 62, 'batches': 100, 'elapsed_time': 93.94, 'total_loss': 0.34674558982253073, 'accuracy': 89.13}
# {'epoch': 62, 'batches': 200, 'elapsed_time': 94.31, 'total_loss': 0.34877024285495284, 'accuracy': 89.15}
# {'epoch': 62, 'batches': 300, 'elapsed_time': 94.88, 'total_loss': 0.34896929274002714, 'accuracy': 88.96}
# {'epoch': 63, 'batches': 100, 'elapsed_time': 95.48, 'total_loss': 0.34510018944740295, 'accuracy': 89.17}
# {'epoch': 63, 'batches': 200, 'elapsed_time': 95.85, 'total_loss': 0.34202583707869055, 'accuracy': 89.18}
# {'epoch': 63, 'batches': 300, 'elapsed_time': 96.28, 'total_loss': 0.3484271124502023, 'accuracy': 89.19}
# {'epoch': 64, 'batches': 100, 'elapsed_time': 96.79, 'total_loss': 0.34543286070227625, 'accuracy': 89.34}
# {'epoch': 64, 'batches': 200, 'elapsed_time': 97.2, 'total_loss': 0.3480097135156393, 'accuracy': 89.06}
# {'epoch': 64, 'batches': 300, 'elapsed_time': 97.63, 'total_loss': 0.3478923918803533, 'accuracy': 89.35}
# {'epoch': 65, 'batches': 100, 'elapsed_time': 98.47, 'total_loss': 0.35240208730101585, 'accuracy': 89.21}
# {'epoch': 65, 'batches': 200, 'elapsed_time': 98.98, 'total_loss': 0.34417392492294313, 'accuracy': 89.26}
# {'epoch': 65, 'batches': 300, 'elapsed_time': 99.48, 'total_loss': 0.34700185065468153, 'accuracy': 89.33}
# {'epoch': 66, 'batches': 100, 'elapsed_time': 99.89, 'total_loss': 0.3431026354432106, 'accuracy': 89.23}
# {'epoch': 66, 'batches': 200, 'elapsed_time': 100.31, 'total_loss': 0.3483467157930136, 'accuracy': 89.16}
# {'epoch': 66, 'batches': 300, 'elapsed_time': 100.83, 'total_loss': 0.3470205004513264, 'accuracy': 89.21}
# {'epoch': 67, 'batches': 100, 'elapsed_time': 101.34, 'total_loss': 0.34384519651532175, 'accuracy': 89.27}
# {'epoch': 67, 'batches': 200, 'elapsed_time': 101.9, 'total_loss': 0.3450914876908064, 'accuracy': 89.31}
# {'epoch': 67, 'batches': 300, 'elapsed_time': 102.32, 'total_loss': 0.34623777161041897, 'accuracy': 89.34}
# {'epoch': 68, 'batches': 100, 'elapsed_time': 102.76, 'total_loss': 0.3427373823523521, 'accuracy': 89.24}
# {'epoch': 68, 'batches': 200, 'elapsed_time': 103.19, 'total_loss': 0.34480529129505155, 'accuracy': 89.2}
# {'epoch': 68, 'batches': 300, 'elapsed_time': 103.69, 'total_loss': 0.34557809914151827, 'accuracy': 89.25}
# {'epoch': 69, 'batches': 100, 'elapsed_time': 104.3, 'total_loss': 0.34145952746272085, 'accuracy': 89.21}
# {'epoch': 69, 'batches': 200, 'elapsed_time': 104.84, 'total_loss': 0.3426308686286211, 'accuracy': 89.36}
# {'epoch': 69, 'batches': 300, 'elapsed_time': 105.25, 'total_loss': 0.3448306788007418, 'accuracy': 89.16}
# {'epoch': 70, 'batches': 100, 'elapsed_time': 105.83, 'total_loss': 0.34819354429841043, 'accuracy': 89.19}
# {'epoch': 70, 'batches': 200, 'elapsed_time': 106.31, 'total_loss': 0.3458894529938698, 'accuracy': 89.32}
# {'epoch': 70, 'batches': 300, 'elapsed_time': 106.66, 'total_loss': 0.344616007010142, 'accuracy': 89.38}
# {'epoch': 71, 'batches': 100, 'elapsed_time': 107.33, 'total_loss': 0.34293894946575165, 'accuracy': 89.34}
# {'epoch': 71, 'batches': 200, 'elapsed_time': 107.84, 'total_loss': 0.3432347296178341, 'accuracy': 89.35}
# {'epoch': 71, 'batches': 300, 'elapsed_time': 108.45, 'total_loss': 0.343829029550155, 'accuracy': 89.2}
# {'epoch': 72, 'batches': 100, 'elapsed_time': 108.93, 'total_loss': 0.341122131049633, 'accuracy': 89.29}
# {'epoch': 72, 'batches': 200, 'elapsed_time': 109.61, 'total_loss': 0.3415509556233883, 'accuracy': 89.18}
# {'epoch': 72, 'batches': 300, 'elapsed_time': 110.16, 'total_loss': 0.3434064047535261, 'accuracy': 89.36}
# {'epoch': 73, 'batches': 100, 'elapsed_time': 110.75, 'total_loss': 0.33873662278056144, 'accuracy': 89.2}
# {'epoch': 73, 'batches': 200, 'elapsed_time': 111.24, 'total_loss': 0.34385189346969125, 'accuracy': 89.26}
# {'epoch': 73, 'batches': 300, 'elapsed_time': 111.9, 'total_loss': 0.3429751378794511, 'accuracy': 89.14}
# {'epoch': 74, 'batches': 100, 'elapsed_time': 112.55, 'total_loss': 0.3362878434360027, 'accuracy': 89.42}
# {'epoch': 74, 'batches': 200, 'elapsed_time': 113.05, 'total_loss': 0.33589977733790877, 'accuracy': 89.34}
# {'epoch': 74, 'batches': 300, 'elapsed_time': 113.45, 'total_loss': 0.3422920713822047, 'accuracy': 89.58}
# {'epoch': 75, 'batches': 100, 'elapsed_time': 113.97, 'total_loss': 0.3496164683997631, 'accuracy': 89.41}
# {'epoch': 75, 'batches': 200, 'elapsed_time': 114.5, 'total_loss': 0.3481568441540003, 'accuracy': 89.36}
# {'epoch': 75, 'batches': 300, 'elapsed_time': 114.95, 'total_loss': 0.3418727091451486, 'accuracy': 89.28}
# {'epoch': 76, 'batches': 100, 'elapsed_time': 115.84, 'total_loss': 0.33928433403372765, 'accuracy': 89.34}
# {'epoch': 76, 'batches': 200, 'elapsed_time': 116.33, 'total_loss': 0.3396412418037653, 'accuracy': 89.31}
# {'epoch': 76, 'batches': 300, 'elapsed_time': 116.83, 'total_loss': 0.3409745007753372, 'accuracy': 89.33}
# {'epoch': 77, 'batches': 100, 'elapsed_time': 117.18, 'total_loss': 0.340316274613142, 'accuracy': 89.38}
# {'epoch': 77, 'batches': 200, 'elapsed_time': 117.5, 'total_loss': 0.33954106368124487, 'accuracy': 89.48}
# {'epoch': 77, 'batches': 300, 'elapsed_time': 117.92, 'total_loss': 0.3405349871516228, 'accuracy': 89.51}
# {'epoch': 78, 'batches': 100, 'elapsed_time': 118.27, 'total_loss': 0.34413043707609176, 'accuracy': 89.46}
# {'epoch': 78, 'batches': 200, 'elapsed_time': 118.57, 'total_loss': 0.3399383608996868, 'accuracy': 89.46}
# {'epoch': 78, 'batches': 300, 'elapsed_time': 118.91, 'total_loss': 0.3408921591937542, 'accuracy': 89.45}
# {'epoch': 79, 'batches': 100, 'elapsed_time': 119.3, 'total_loss': 0.3381583821773529, 'accuracy': 89.4}
# {'epoch': 79, 'batches': 200, 'elapsed_time': 119.63, 'total_loss': 0.3385394389182329, 'accuracy': 89.32}
# {'epoch': 79, 'batches': 300, 'elapsed_time': 120.16, 'total_loss': 0.3397028954823812, 'accuracy': 89.57}
# {'epoch': 80, 'batches': 100, 'elapsed_time': 120.65, 'total_loss': 0.3354370792210102, 'accuracy': 89.44}
# {'epoch': 80, 'batches': 200, 'elapsed_time': 121.18, 'total_loss': 0.3425522846728563, 'accuracy': 89.55}
# {'epoch': 80, 'batches': 300, 'elapsed_time': 121.48, 'total_loss': 0.3392758653561274, 'accuracy': 89.46}
# {'epoch': 81, 'batches': 100, 'elapsed_time': 121.87, 'total_loss': 0.3415898495912552, 'accuracy': 89.45}
# {'epoch': 81, 'batches': 200, 'elapsed_time': 122.29, 'total_loss': 0.3400133680552244, 'accuracy': 89.54}
# {'epoch': 81, 'batches': 300, 'elapsed_time': 122.67, 'total_loss': 0.3389592508971691, 'accuracy': 89.54}
# {'epoch': 82, 'batches': 100, 'elapsed_time': 123.07, 'total_loss': 0.3365834863483906, 'accuracy': 89.62}
# {'epoch': 82, 'batches': 200, 'elapsed_time': 123.51, 'total_loss': 0.3375185897946358, 'accuracy': 89.45}
# {'epoch': 82, 'batches': 300, 'elapsed_time': 123.99, 'total_loss': 0.3383541795114676, 'accuracy': 89.49}
# {'epoch': 83, 'batches': 100, 'elapsed_time': 124.65, 'total_loss': 0.33875751957297323, 'accuracy': 89.47}
# {'epoch': 83, 'batches': 200, 'elapsed_time': 125.25, 'total_loss': 0.341410603672266, 'accuracy': 89.42}
# {'epoch': 83, 'batches': 300, 'elapsed_time': 125.75, 'total_loss': 0.33791913092136383, 'accuracy': 89.37}
# {'epoch': 84, 'batches': 100, 'elapsed_time': 126.1, 'total_loss': 0.3353701722621918, 'accuracy': 89.61}
# {'epoch': 84, 'batches': 200, 'elapsed_time': 126.69, 'total_loss': 0.3329347790032625, 'accuracy': 89.43}
# {'epoch': 84, 'batches': 300, 'elapsed_time': 127.02, 'total_loss': 0.33744507307807603, 'accuracy': 89.39}
# {'epoch': 85, 'batches': 100, 'elapsed_time': 127.33, 'total_loss': 0.3302785974740982, 'accuracy': 89.52}
# {'epoch': 85, 'batches': 200, 'elapsed_time': 127.77, 'total_loss': 0.33331951171159746, 'accuracy': 89.53}
# {'epoch': 85, 'batches': 300, 'elapsed_time': 128.15, 'total_loss': 0.3370675257841746, 'accuracy': 89.59}
# {'epoch': 86, 'batches': 100, 'elapsed_time': 128.64, 'total_loss': 0.3372915361821651, 'accuracy': 89.55}
# {'epoch': 86, 'batches': 200, 'elapsed_time': 128.98, 'total_loss': 0.3385889432579279, 'accuracy': 89.55}
# {'epoch': 86, 'batches': 300, 'elapsed_time': 129.35, 'total_loss': 0.3372369837760925, 'accuracy': 89.44}
# {'epoch': 87, 'batches': 100, 'elapsed_time': 129.77, 'total_loss': 0.3403564703464508, 'accuracy': 89.4}
# {'epoch': 87, 'batches': 200, 'elapsed_time': 130.19, 'total_loss': 0.33596115045249464, 'accuracy': 89.61}
# {'epoch': 87, 'batches': 300, 'elapsed_time': 130.47, 'total_loss': 0.3373941629131635, 'accuracy': 89.56}
# {'epoch': 88, 'batches': 100, 'elapsed_time': 131.06, 'total_loss': 0.33454967886209486, 'accuracy': 89.51}
# {'epoch': 88, 'batches': 200, 'elapsed_time': 131.62, 'total_loss': 0.3339115345478058, 'accuracy': 89.44}
# {'epoch': 88, 'batches': 300, 'elapsed_time': 132.13, 'total_loss': 0.33653283243378, 'accuracy': 89.62}
# {'epoch': 89, 'batches': 100, 'elapsed_time': 132.47, 'total_loss': 0.33675906851887705, 'accuracy': 89.57}
# {'epoch': 89, 'batches': 200, 'elapsed_time': 132.93, 'total_loss': 0.3348394671082497, 'accuracy': 89.55}
# {'epoch': 89, 'batches': 300, 'elapsed_time': 133.44, 'total_loss': 0.33544035722812016, 'accuracy': 89.45}
# {'epoch': 90, 'batches': 100, 'elapsed_time': 133.93, 'total_loss': 0.33353895112872123, 'accuracy': 89.41}
# {'epoch': 90, 'batches': 200, 'elapsed_time': 134.54, 'total_loss': 0.3334618382155895, 'accuracy': 89.62}
# {'epoch': 90, 'batches': 300, 'elapsed_time': 135.05, 'total_loss': 0.335585324416558, 'accuracy': 89.66}
# {'epoch': 91, 'batches': 100, 'elapsed_time': 135.5, 'total_loss': 0.33920581415295603, 'accuracy': 89.55}
# {'epoch': 91, 'batches': 200, 'elapsed_time': 135.97, 'total_loss': 0.337348465770483, 'accuracy': 89.73}
# {'epoch': 91, 'batches': 300, 'elapsed_time': 136.41, 'total_loss': 0.3350675670802593, 'accuracy': 89.54}
# {'epoch': 92, 'batches': 100, 'elapsed_time': 136.88, 'total_loss': 0.3364733719825745, 'accuracy': 89.5}
# {'epoch': 92, 'batches': 200, 'elapsed_time': 137.3, 'total_loss': 0.33212615132331846, 'accuracy': 89.66}
# {'epoch': 92, 'batches': 300, 'elapsed_time': 137.72, 'total_loss': 0.33459463755289715, 'accuracy': 89.54}
# {'epoch': 93, 'batches': 100, 'elapsed_time': 138.29, 'total_loss': 0.3265168486535549, 'accuracy': 89.71}
# {'epoch': 93, 'batches': 200, 'elapsed_time': 138.92, 'total_loss': 0.33391753561794757, 'accuracy': 89.52}
# {'epoch': 93, 'batches': 300, 'elapsed_time': 139.22, 'total_loss': 0.334717576255401, 'accuracy': 89.7}
# {'epoch': 94, 'batches': 100, 'elapsed_time': 139.55, 'total_loss': 0.3382533350586891, 'accuracy': 89.51}
# {'epoch': 94, 'batches': 200, 'elapsed_time': 139.89, 'total_loss': 0.33558916293084623, 'accuracy': 89.74}
# {'epoch': 94, 'batches': 300, 'elapsed_time': 140.23, 'total_loss': 0.33384253576397893, 'accuracy': 89.59}
# {'epoch': 95, 'batches': 100, 'elapsed_time': 140.49, 'total_loss': 0.3327081422507763, 'accuracy': 89.37}
# {'epoch': 95, 'batches': 200, 'elapsed_time': 140.79, 'total_loss': 0.3352085228264332, 'accuracy': 89.76}
# {'epoch': 95, 'batches': 300, 'elapsed_time': 141.13, 'total_loss': 0.3338590763509274, 'accuracy': 89.63}
# {'epoch': 96, 'batches': 100, 'elapsed_time': 141.41, 'total_loss': 0.3416530993580818, 'accuracy': 89.72}
# {'epoch': 96, 'batches': 200, 'elapsed_time': 141.78, 'total_loss': 0.3346149630844593, 'accuracy': 89.69}
# {'epoch': 96, 'batches': 300, 'elapsed_time': 142.12, 'total_loss': 0.3335115072627862, 'accuracy': 89.6}
# {'epoch': 97, 'batches': 100, 'elapsed_time': 142.71, 'total_loss': 0.3281887078285217, 'accuracy': 89.58}
# {'epoch': 97, 'batches': 200, 'elapsed_time': 143.29, 'total_loss': 0.3295521694421768, 'accuracy': 89.47}
# {'epoch': 97, 'batches': 300, 'elapsed_time': 143.62, 'total_loss': 0.33309139976898827, 'accuracy': 89.78}
# {'epoch': 98, 'batches': 100, 'elapsed_time': 143.94, 'total_loss': 0.3203760403394699, 'accuracy': 89.68}
# {'epoch': 98, 'batches': 200, 'elapsed_time': 144.37, 'total_loss': 0.32804924465715884, 'accuracy': 89.76}
# {'epoch': 98, 'batches': 300, 'elapsed_time': 144.8, 'total_loss': 0.332823699315389, 'accuracy': 89.65}
# {'epoch': 99, 'batches': 100, 'elapsed_time': 145.08, 'total_loss': 0.33398627370595935, 'accuracy': 89.69}
# {'epoch': 99, 'batches': 200, 'elapsed_time': 145.47, 'total_loss': 0.331755485534668, 'accuracy': 89.93}
# {'epoch': 99, 'batches': 300, 'elapsed_time': 145.79, 'total_loss': 0.3321118757625421, 'accuracy': 89.54}
# {'epoch': 100, 'batches': 100, 'elapsed_time': 146.07, 'total_loss': 0.32891049429774283, 'accuracy': 89.74}
# {'epoch': 100, 'batches': 200, 'elapsed_time': 146.33, 'total_loss': 0.33266160875558853, 'accuracy': 89.77}
# {'epoch': 100, 'batches': 300, 'elapsed_time': 146.76, 'total_loss': 0.3322080802420775, 'accuracy': 89.72}
# {'epoch': 101, 'batches': 100, 'elapsed_time': 147.24, 'total_loss': 0.33185030475258825, 'accuracy': 89.7}
# {'epoch': 101, 'batches': 200, 'elapsed_time': 147.61, 'total_loss': 0.3371625231951475, 'accuracy': 89.75}
# {'epoch': 101, 'batches': 300, 'elapsed_time': 148.02, 'total_loss': 0.3323937471707662, 'accuracy': 89.75}
# {'epoch': 102, 'batches': 100, 'elapsed_time': 148.38, 'total_loss': 0.3257795453071594, 'accuracy': 89.55}
# {'epoch': 102, 'batches': 200, 'elapsed_time': 148.71, 'total_loss': 0.3292488147318363, 'accuracy': 89.63}
# {'epoch': 102, 'batches': 300, 'elapsed_time': 149.24, 'total_loss': 0.3319334273537, 'accuracy': 89.59}
# {'epoch': 103, 'batches': 100, 'elapsed_time': 149.57, 'total_loss': 0.3283678278326988, 'accuracy': 89.72}
# {'epoch': 103, 'batches': 200, 'elapsed_time': 149.93, 'total_loss': 0.3274495457857847, 'accuracy': 89.72}
# {'epoch': 103, 'batches': 300, 'elapsed_time': 150.44, 'total_loss': 0.33137073248624804, 'accuracy': 89.72}
# {'epoch': 104, 'batches': 100, 'elapsed_time': 150.87, 'total_loss': 0.32697334051132204, 'accuracy': 89.56}
# {'epoch': 104, 'batches': 200, 'elapsed_time': 151.22, 'total_loss': 0.3330654782801867, 'accuracy': 89.5}
# {'epoch': 104, 'batches': 300, 'elapsed_time': 151.63, 'total_loss': 0.3314113415280978, 'accuracy': 89.49}
# {'epoch': 105, 'batches': 100, 'elapsed_time': 152.0, 'total_loss': 0.33394940078258517, 'accuracy': 89.68}
# {'epoch': 105, 'batches': 200, 'elapsed_time': 152.44, 'total_loss': 0.32879479803144934, 'accuracy': 89.54}
# {'epoch': 105, 'batches': 300, 'elapsed_time': 152.71, 'total_loss': 0.33126064787308374, 'accuracy': 89.71}
# {'epoch': 106, 'batches': 100, 'elapsed_time': 153.1, 'total_loss': 0.3256388935446739, 'accuracy': 89.85}
# {'epoch': 106, 'batches': 200, 'elapsed_time': 153.49, 'total_loss': 0.3313097968697548, 'accuracy': 89.82}
# {'epoch': 106, 'batches': 300, 'elapsed_time': 153.98, 'total_loss': 0.3304525189101696, 'accuracy': 89.61}
# {'epoch': 107, 'batches': 100, 'elapsed_time': 154.56, 'total_loss': 0.3312154592573643, 'accuracy': 89.67}
# {'epoch': 107, 'batches': 200, 'elapsed_time': 155.05, 'total_loss': 0.329036832600832, 'accuracy': 89.73}
# {'epoch': 107, 'batches': 300, 'elapsed_time': 155.42, 'total_loss': 0.3308513389527798, 'accuracy': 89.67}
# {'epoch': 108, 'batches': 100, 'elapsed_time': 155.87, 'total_loss': 0.32657921105623244, 'accuracy': 89.8}
# {'epoch': 108, 'batches': 200, 'elapsed_time': 156.29, 'total_loss': 0.3285383968055248, 'accuracy': 89.77}
# {'epoch': 108, 'batches': 300, 'elapsed_time': 156.85, 'total_loss': 0.3304530758659045, 'accuracy': 89.82}
# {'epoch': 109, 'batches': 100, 'elapsed_time': 157.29, 'total_loss': 0.33763763785362244, 'accuracy': 89.89}
# {'epoch': 109, 'batches': 200, 'elapsed_time': 157.68, 'total_loss': 0.33104048140347003, 'accuracy': 89.73}
# {'epoch': 109, 'batches': 300, 'elapsed_time': 157.95, 'total_loss': 0.3303389659027259, 'accuracy': 89.58}
# {'epoch': 110, 'batches': 100, 'elapsed_time': 158.21, 'total_loss': 0.32807293891906736, 'accuracy': 89.79}
# {'epoch': 110, 'batches': 200, 'elapsed_time': 158.48, 'total_loss': 0.32944812208414076, 'accuracy': 89.6}
# {'epoch': 110, 'batches': 300, 'elapsed_time': 158.9, 'total_loss': 0.3299902857343356, 'accuracy': 89.73}
# {'epoch': 111, 'batches': 100, 'elapsed_time': 159.32, 'total_loss': 0.32313927471637727, 'accuracy': 89.78}
# {'epoch': 111, 'batches': 200, 'elapsed_time': 159.74, 'total_loss': 0.3275285578519106, 'accuracy': 89.73}
# {'epoch': 111, 'batches': 300, 'elapsed_time': 160.23, 'total_loss': 0.32985237896442415, 'accuracy': 89.84}
# {'epoch': 112, 'batches': 100, 'elapsed_time': 160.65, 'total_loss': 0.33706840738654137, 'accuracy': 89.74}
# {'epoch': 112, 'batches': 200, 'elapsed_time': 161.04, 'total_loss': 0.3286777612566948, 'accuracy': 89.74}
# {'epoch': 112, 'batches': 300, 'elapsed_time': 161.49, 'total_loss': 0.32936275055011116, 'accuracy': 89.87}
# {'epoch': 113, 'batches': 100, 'elapsed_time': 162.0, 'total_loss': 0.3266088739037514, 'accuracy': 89.59}
# {'epoch': 113, 'batches': 200, 'elapsed_time': 162.35, 'total_loss': 0.32803220696747304, 'accuracy': 89.72}
# {'epoch': 113, 'batches': 300, 'elapsed_time': 162.65, 'total_loss': 0.32963327745596566, 'accuracy': 89.52}
# {'epoch': 114, 'batches': 100, 'elapsed_time': 163.0, 'total_loss': 0.3309786461293697, 'accuracy': 89.5}
# {'epoch': 114, 'batches': 200, 'elapsed_time': 163.47, 'total_loss': 0.3304669438302517, 'accuracy': 89.91}
# {'epoch': 114, 'batches': 300, 'elapsed_time': 163.87, 'total_loss': 0.32903840894500413, 'accuracy': 89.84}
# {'epoch': 115, 'batches': 100, 'elapsed_time': 164.37, 'total_loss': 0.32834925532341, 'accuracy': 89.84}
# {'epoch': 115, 'batches': 200, 'elapsed_time': 164.85, 'total_loss': 0.3311036736518145, 'accuracy': 89.98}
# {'epoch': 115, 'batches': 300, 'elapsed_time': 165.22, 'total_loss': 0.3290116729338964, 'accuracy': 89.65}
# {'epoch': 116, 'batches': 100, 'elapsed_time': 165.76, 'total_loss': 0.3168259619176388, 'accuracy': 89.49}
# {'epoch': 116, 'batches': 200, 'elapsed_time': 166.05, 'total_loss': 0.326583698540926, 'accuracy': 89.55}
# {'epoch': 116, 'batches': 300, 'elapsed_time': 166.43, 'total_loss': 0.32903161098559697, 'accuracy': 89.72}
# {'epoch': 117, 'batches': 100, 'elapsed_time': 166.8, 'total_loss': 0.33460911870002746, 'accuracy': 89.49}
# {'epoch': 117, 'batches': 200, 'elapsed_time': 167.17, 'total_loss': 0.3297801396995783, 'accuracy': 89.79}
# {'epoch': 117, 'batches': 300, 'elapsed_time': 167.55, 'total_loss': 0.3285939728220304, 'accuracy': 89.86}
# {'epoch': 118, 'batches': 100, 'elapsed_time': 167.94, 'total_loss': 0.32591437920928, 'accuracy': 89.9}
# {'epoch': 118, 'batches': 200, 'elapsed_time': 168.34, 'total_loss': 0.3271304351091385, 'accuracy': 89.77}
# {'epoch': 118, 'batches': 300, 'elapsed_time': 168.66, 'total_loss': 0.32894704073667524, 'accuracy': 89.68}
# {'epoch': 119, 'batches': 100, 'elapsed_time': 169.03, 'total_loss': 0.3248978762328625, 'accuracy': 89.7}
# {'epoch': 119, 'batches': 200, 'elapsed_time': 169.38, 'total_loss': 0.32568091340363026, 'accuracy': 89.62}
# {'epoch': 119, 'batches': 300, 'elapsed_time': 169.92, 'total_loss': 0.3287074258923531, 'accuracy': 89.98}
# {'epoch': 120, 'batches': 100, 'elapsed_time': 170.3, 'total_loss': 0.32940843313932416, 'accuracy': 89.75}
# {'epoch': 120, 'batches': 200, 'elapsed_time': 170.6, 'total_loss': 0.32749352283775807, 'accuracy': 89.79}
# {'epoch': 120, 'batches': 300, 'elapsed_time': 170.89, 'total_loss': 0.32850566322604813, 'accuracy': 89.76}
# {'epoch': 121, 'batches': 100, 'elapsed_time': 171.27, 'total_loss': 0.33228136524558066, 'accuracy': 89.77}
# {'epoch': 121, 'batches': 200, 'elapsed_time': 171.58, 'total_loss': 0.3270516922324896, 'accuracy': 89.99}
# {'epoch': 121, 'batches': 300, 'elapsed_time': 171.97, 'total_loss': 0.3278223587075869, 'accuracy': 89.82}
# {'epoch': 122, 'batches': 100, 'elapsed_time': 172.26, 'total_loss': 0.3303938855230808, 'accuracy': 89.78}
# {'epoch': 122, 'batches': 200, 'elapsed_time': 172.54, 'total_loss': 0.3291684111207724, 'accuracy': 89.73}
# {'epoch': 122, 'batches': 300, 'elapsed_time': 172.82, 'total_loss': 0.3277418457965056, 'accuracy': 89.81}
# {'epoch': 123, 'batches': 100, 'elapsed_time': 173.15, 'total_loss': 0.3331800538301468, 'accuracy': 89.85}
# {'epoch': 123, 'batches': 200, 'elapsed_time': 173.52, 'total_loss': 0.3299000120908022, 'accuracy': 89.85}
# {'epoch': 123, 'batches': 300, 'elapsed_time': 173.96, 'total_loss': 0.3277212943136692, 'accuracy': 89.94}
# {'epoch': 124, 'batches': 100, 'elapsed_time': 174.29, 'total_loss': 0.3304384565353394, 'accuracy': 89.84}
# {'epoch': 124, 'batches': 200, 'elapsed_time': 174.62, 'total_loss': 0.328768867328763, 'accuracy': 89.82}
# {'epoch': 124, 'batches': 300, 'elapsed_time': 175.05, 'total_loss': 0.3272921402255694, 'accuracy': 89.86}
# {'epoch': 125, 'batches': 100, 'elapsed_time': 175.52, 'total_loss': 0.33234944954514506, 'accuracy': 89.85}
# {'epoch': 125, 'batches': 200, 'elapsed_time': 175.78, 'total_loss': 0.3247776747494936, 'accuracy': 90.02}
# {'epoch': 125, 'batches': 300, 'elapsed_time': 176.07, 'total_loss': 0.32706552252173426, 'accuracy': 89.89}
# {'epoch': 126, 'batches': 100, 'elapsed_time': 176.34, 'total_loss': 0.333314288854599, 'accuracy': 89.8}
# {'epoch': 126, 'batches': 200, 'elapsed_time': 176.69, 'total_loss': 0.32966206684708593, 'accuracy': 89.82}
# {'epoch': 126, 'batches': 300, 'elapsed_time': 177.02, 'total_loss': 0.32682780891656876, 'accuracy': 89.71}
# {'epoch': 127, 'batches': 100, 'elapsed_time': 177.54, 'total_loss': 0.3242161336541176, 'accuracy': 89.96}
# {'epoch': 127, 'batches': 200, 'elapsed_time': 177.89, 'total_loss': 0.327148686721921, 'accuracy': 89.95}
# {'epoch': 127, 'batches': 300, 'elapsed_time': 178.25, 'total_loss': 0.32696002135674157, 'accuracy': 89.88}

# %%
def predict(inputs, w1, w2, b):
    hid = (inputs @ w1).astype(np.int16)
    hid = hid * (hid > 0)
    out = hid @ w2 + b
    return np.argmax(out, axis=1)


def clip(arr, scale, bits):
    imax = 2 ** (bits - 1) - 1
    imin = -(2 ** (bits - 1))

    return np.clip(arr * scale, imin, imax)

# %%
data = []

weight1 = net.layer1.weight.detach().numpy().transpose()
weight2 = net.layer2.weight.detach().numpy().transpose()
bias = net.layer2.bias.detach().numpy()

for i in range(0, 32):
    SCALE = 1 << i

    img = test_inputs.numpy().astype(np.uint8)
    w1 = clip(weight1, SCALE, 8).astype(np.int8)
    w2 = clip(weight2, SCALE, 8).astype(np.int8)
    b = clip(bias, SCALE, 16).astype(np.int16)

    pred = predict(img, w1, w2, b)
    data.append(
        {
            "pow": i,
            "scale": SCALE,
            "accuracy": sum(pred == test_labels.numpy()) / len(test_labels),
        }
    )

stat = pd.DataFrame(data)
scale = stat.set_index("scale")["accuracy"].idxmax()
stat[stat["scale"] == scale]
# Out:
#    pow  scale  accuracy
# 5    5     32    0.8892

# %%
fig, ax = plt.subplots(figsize=(8, 5), dpi=120)
ax.scatter(stat["scale"], stat["accuracy"] * 100)
ax.axhline(y=85, color="orange", linestyle="dashed")
ax.set_xscale("log", base=2)
ax.set_xlabel("Scale")
ax.set_xlim(1, 2**32)
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 100)
fig.tight_layout()
fig.savefig("customized.pdf")
fig.savefig("customized.png")

# %%
np.save("test_data_custom", test_inputs.numpy().astype(np.uint8))
np.save("test_label_custom", test_labels)
np.save("model_weight1_custom", clip(weight1, scale, 8).astype(np.int8))
np.save("model_weight2_custom", clip(weight2, scale, 8).astype(np.int8))
np.save("model_bias_custom", clip(bias, scale, 16).astype(np.int16))

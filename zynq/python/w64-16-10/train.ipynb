# %%
import struct
import time
from pathlib import Path

from matplotlib import pyplot as plt
from torchvision import transforms
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
def load_label(filename):
    with open(filename, "rb") as flbl:
        magic, num = struct.unpack(">II", flbl.read(8))
        return np.fromfile(flbl, dtype=np.int8)


def load_data(filename):
    with open(filename, "rb") as fimg:
        magic, num, rows, cols = struct.unpack(">IIII", fimg.read(16))
        return np.fromfile(fimg, dtype=np.uint8).reshape(num, rows, cols)


BASE = Path("./mnist")

train_images = torch.tensor(load_data(BASE / "train-images-idx3-ubyte")).long()
train_labels = torch.tensor(load_label(BASE / "train-labels-idx1-ubyte")).long()
test_images = torch.tensor(load_data(BASE / "t10k-images-idx3-ubyte")).long()
test_labels = torch.tensor(load_label(BASE / "t10k-labels-idx1-ubyte")).long()

print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([60000])
# torch.Size([10000, 28, 28])
# torch.Size([10000])

# %%
class MLP(nn.Module):
    def __init__(self, input_size, output_size=10):
        super().__init__()
        self.layer1 = nn.Linear(input_size, 16, bias=False)
        self.layer2 = nn.Linear(16, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = F.relu(x)
        return self.layer2(x)

# %%
def normalize_input(images, size, depth):
    resize = transforms.Resize(size)
    images = resize(images).long()
    images = torch.flatten(images, start_dim=1)
    return images >> (8 - depth)

# %%
BATCH_SIZE = 200
INPUT_SIZE = 8
INPUT_DEPTH = 4
INPUT_COUNT = train_labels.shape[0]

net = MLP(INPUT_SIZE**2)


train_inputs = normalize_input(train_images, INPUT_SIZE, INPUT_DEPTH)
test_inputs = normalize_input(test_images, INPUT_SIZE, INPUT_DEPTH)
train_output = F.one_hot(train_labels, num_classes=10)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)


start = time.time()
for epoch in range(32):
    running_loss = 0
    running_error = 0
    num_batches = 0
    shuffled_indices = torch.randperm(INPUT_COUNT)
    for count in range(0, INPUT_COUNT, BATCH_SIZE):
        indices = shuffled_indices[count : count + BATCH_SIZE]

        batch_inputs = train_inputs[indices]
        batch_output = train_output[indices]

        # forward and backward pass
        optimizer.zero_grad()
        loss = criterion(net(batch_inputs.float()), batch_output.float())
        loss.backward()
        optimizer.step()

        # compute some stats
        running_loss += loss.detach().item()
        num_batches += 1

        total_loss = running_loss / num_batches
        # total_error = running_error / num_batches
        elapsed_time = time.time() - start

        if num_batches % 100 == 0:
            with torch.no_grad():
                outputs = net(test_inputs.float())
                correct = sum(outputs.argmax(dim=1) == test_labels).item()

            print(
                {
                    "epoch": epoch,
                    "batches": num_batches,
                    "elapsed_time": round(elapsed_time, 2),
                    "total_loss": total_loss,
                    "accuracy": round(correct / len(test_inputs) * 100, 2),
                }
            )
# Out:
# {'epoch': 0, 'batches': 100, 'elapsed_time': 1.06, 'total_loss': 1.884160852432251, 'accuracy': 61.41}
# {'epoch': 0, 'batches': 200, 'elapsed_time': 2.22, 'total_loss': 1.4602892306447028, 'accuracy': 75.36}
# {'epoch': 0, 'batches': 300, 'elapsed_time': 3.57, 'total_loss': 1.2368042226632436, 'accuracy': 78.57}
# {'epoch': 1, 'batches': 100, 'elapsed_time': 4.8, 'total_loss': 0.703439564704895, 'accuracy': 80.5}
# {'epoch': 1, 'batches': 200, 'elapsed_time': 6.22, 'total_loss': 0.6813731861114501, 'accuracy': 81.54}
# {'epoch': 1, 'batches': 300, 'elapsed_time': 7.34, 'total_loss': 0.6646083465218544, 'accuracy': 81.94}
# {'epoch': 2, 'batches': 100, 'elapsed_time': 8.46, 'total_loss': 0.6162484166026115, 'accuracy': 82.74}
# {'epoch': 2, 'batches': 200, 'elapsed_time': 9.42, 'total_loss': 0.6057436583936214, 'accuracy': 83.05}
# {'epoch': 2, 'batches': 300, 'elapsed_time': 10.79, 'total_loss': 0.5942278824249904, 'accuracy': 83.5}
# {'epoch': 3, 'batches': 100, 'elapsed_time': 11.79, 'total_loss': 0.5669846895337105, 'accuracy': 83.69}
# {'epoch': 3, 'batches': 200, 'elapsed_time': 12.84, 'total_loss': 0.5572637212276459, 'accuracy': 84.04}
# {'epoch': 3, 'batches': 300, 'elapsed_time': 14.14, 'total_loss': 0.5556204068660736, 'accuracy': 84.57}
# {'epoch': 4, 'batches': 100, 'elapsed_time': 15.36, 'total_loss': 0.541566691994667, 'accuracy': 84.6}
# {'epoch': 4, 'batches': 200, 'elapsed_time': 17.05, 'total_loss': 0.5381388145685196, 'accuracy': 84.81}
# {'epoch': 4, 'batches': 300, 'elapsed_time': 18.54, 'total_loss': 0.5290679829319318, 'accuracy': 84.92}
# {'epoch': 5, 'batches': 100, 'elapsed_time': 19.68, 'total_loss': 0.521764515042305, 'accuracy': 85.08}
# {'epoch': 5, 'batches': 200, 'elapsed_time': 21.39, 'total_loss': 0.5106092102825641, 'accuracy': 85.17}
# {'epoch': 5, 'batches': 300, 'elapsed_time': 22.94, 'total_loss': 0.5088598656654358, 'accuracy': 85.3}
# {'epoch': 6, 'batches': 100, 'elapsed_time': 24.15, 'total_loss': 0.497501335144043, 'accuracy': 85.58}
# {'epoch': 6, 'batches': 200, 'elapsed_time': 25.21, 'total_loss': 0.4932267090678215, 'accuracy': 85.6}
# {'epoch': 6, 'batches': 300, 'elapsed_time': 26.57, 'total_loss': 0.4933353461821874, 'accuracy': 85.77}
# {'epoch': 7, 'batches': 100, 'elapsed_time': 27.64, 'total_loss': 0.48468368262052536, 'accuracy': 85.76}
# {'epoch': 7, 'batches': 200, 'elapsed_time': 28.45, 'total_loss': 0.48481817334890365, 'accuracy': 85.91}
# {'epoch': 7, 'batches': 300, 'elapsed_time': 29.58, 'total_loss': 0.4801050281524658, 'accuracy': 86.05}
# {'epoch': 8, 'batches': 100, 'elapsed_time': 30.53, 'total_loss': 0.46732670336961746, 'accuracy': 86.31}
# {'epoch': 8, 'batches': 200, 'elapsed_time': 31.68, 'total_loss': 0.47039691999554634, 'accuracy': 86.46}
# {'epoch': 8, 'batches': 300, 'elapsed_time': 32.54, 'total_loss': 0.46900036225716274, 'accuracy': 86.47}
# {'epoch': 9, 'batches': 100, 'elapsed_time': 33.43, 'total_loss': 0.4548917692899704, 'accuracy': 86.28}
# {'epoch': 9, 'batches': 200, 'elapsed_time': 34.26, 'total_loss': 0.46145519137382507, 'accuracy': 86.54}
# {'epoch': 9, 'batches': 300, 'elapsed_time': 34.92, 'total_loss': 0.4593159187833468, 'accuracy': 86.6}
# {'epoch': 10, 'batches': 100, 'elapsed_time': 35.79, 'total_loss': 0.45304118931293486, 'accuracy': 86.6}
# {'epoch': 10, 'batches': 200, 'elapsed_time': 37.54, 'total_loss': 0.4537141565978527, 'accuracy': 86.86}
# {'epoch': 10, 'batches': 300, 'elapsed_time': 38.72, 'total_loss': 0.4507222339510918, 'accuracy': 86.87}
# {'epoch': 11, 'batches': 100, 'elapsed_time': 40.12, 'total_loss': 0.44455582976341246, 'accuracy': 87.04}
# {'epoch': 11, 'batches': 200, 'elapsed_time': 41.4, 'total_loss': 0.4454379573464394, 'accuracy': 86.98}
# {'epoch': 11, 'batches': 300, 'elapsed_time': 42.84, 'total_loss': 0.44334288269281386, 'accuracy': 87.13}
# {'epoch': 12, 'batches': 100, 'elapsed_time': 44.15, 'total_loss': 0.4432443457841873, 'accuracy': 87.04}
# {'epoch': 12, 'batches': 200, 'elapsed_time': 45.17, 'total_loss': 0.4371959161758423, 'accuracy': 87.36}
# {'epoch': 12, 'batches': 300, 'elapsed_time': 46.28, 'total_loss': 0.4363070870439211, 'accuracy': 87.03}
# {'epoch': 13, 'batches': 100, 'elapsed_time': 47.68, 'total_loss': 0.43516647547483445, 'accuracy': 87.1}
# {'epoch': 13, 'batches': 200, 'elapsed_time': 49.43, 'total_loss': 0.4309267120063305, 'accuracy': 87.04}
# {'epoch': 13, 'batches': 300, 'elapsed_time': 50.82, 'total_loss': 0.430013708670934, 'accuracy': 87.16}
# {'epoch': 14, 'batches': 100, 'elapsed_time': 52.08, 'total_loss': 0.4258151748776436, 'accuracy': 87.4}
# {'epoch': 14, 'batches': 200, 'elapsed_time': 53.27, 'total_loss': 0.4222195038199425, 'accuracy': 87.41}
# {'epoch': 14, 'batches': 300, 'elapsed_time': 54.18, 'total_loss': 0.4248698754111926, 'accuracy': 87.3}
# {'epoch': 15, 'batches': 100, 'elapsed_time': 55.2, 'total_loss': 0.4110100999474525, 'accuracy': 87.58}
# {'epoch': 15, 'batches': 200, 'elapsed_time': 56.02, 'total_loss': 0.41637707620859143, 'accuracy': 87.47}
# {'epoch': 15, 'batches': 300, 'elapsed_time': 56.96, 'total_loss': 0.420051686167717, 'accuracy': 87.29}
# {'epoch': 16, 'batches': 100, 'elapsed_time': 58.08, 'total_loss': 0.4231882667541504, 'accuracy': 87.39}
# {'epoch': 16, 'batches': 200, 'elapsed_time': 59.22, 'total_loss': 0.415427927672863, 'accuracy': 87.48}
# {'epoch': 16, 'batches': 300, 'elapsed_time': 60.39, 'total_loss': 0.41552030384540556, 'accuracy': 87.62}
# {'epoch': 17, 'batches': 100, 'elapsed_time': 61.76, 'total_loss': 0.41372326970100404, 'accuracy': 87.32}
# {'epoch': 17, 'batches': 200, 'elapsed_time': 62.76, 'total_loss': 0.41218759983777997, 'accuracy': 87.56}
# {'epoch': 17, 'batches': 300, 'elapsed_time': 63.83, 'total_loss': 0.41145237813393276, 'accuracy': 87.64}
# {'epoch': 18, 'batches': 100, 'elapsed_time': 64.78, 'total_loss': 0.41255360037088395, 'accuracy': 87.68}
# {'epoch': 18, 'batches': 200, 'elapsed_time': 65.76, 'total_loss': 0.41047305092215536, 'accuracy': 87.78}
# {'epoch': 18, 'batches': 300, 'elapsed_time': 66.53, 'total_loss': 0.40788063098986943, 'accuracy': 87.74}
# {'epoch': 19, 'batches': 100, 'elapsed_time': 67.55, 'total_loss': 0.39627592384815213, 'accuracy': 87.63}
# {'epoch': 19, 'batches': 200, 'elapsed_time': 68.94, 'total_loss': 0.4017566341161728, 'accuracy': 87.35}
# {'epoch': 19, 'batches': 300, 'elapsed_time': 70.26, 'total_loss': 0.40443829903999967, 'accuracy': 87.76}
# {'epoch': 20, 'batches': 100, 'elapsed_time': 71.37, 'total_loss': 0.40460951656103133, 'accuracy': 87.77}
# {'epoch': 20, 'batches': 200, 'elapsed_time': 72.8, 'total_loss': 0.4062404601275921, 'accuracy': 87.8}
# {'epoch': 20, 'batches': 300, 'elapsed_time': 74.02, 'total_loss': 0.4009462323784828, 'accuracy': 87.91}
# {'epoch': 21, 'batches': 100, 'elapsed_time': 75.58, 'total_loss': 0.4043827044963837, 'accuracy': 87.8}
# {'epoch': 21, 'batches': 200, 'elapsed_time': 76.64, 'total_loss': 0.40137369856238364, 'accuracy': 87.86}
# {'epoch': 21, 'batches': 300, 'elapsed_time': 77.81, 'total_loss': 0.397334043631951, 'accuracy': 87.87}
# {'epoch': 22, 'batches': 100, 'elapsed_time': 79.05, 'total_loss': 0.40424193531274794, 'accuracy': 87.84}
# {'epoch': 22, 'batches': 200, 'elapsed_time': 79.9, 'total_loss': 0.3983178616315126, 'accuracy': 87.66}
# {'epoch': 22, 'batches': 300, 'elapsed_time': 80.9, 'total_loss': 0.3956296335160732, 'accuracy': 87.88}
# {'epoch': 23, 'batches': 100, 'elapsed_time': 82.06, 'total_loss': 0.39738898336887357, 'accuracy': 87.87}
# {'epoch': 23, 'batches': 200, 'elapsed_time': 83.17, 'total_loss': 0.39531104266643524, 'accuracy': 87.96}
# {'epoch': 23, 'batches': 300, 'elapsed_time': 84.32, 'total_loss': 0.39223015278577805, 'accuracy': 88.1}
# {'epoch': 24, 'batches': 100, 'elapsed_time': 85.86, 'total_loss': 0.39729760140180587, 'accuracy': 87.95}
# {'epoch': 24, 'batches': 200, 'elapsed_time': 87.27, 'total_loss': 0.38900776863098147, 'accuracy': 88.1}
# {'epoch': 24, 'batches': 300, 'elapsed_time': 88.7, 'total_loss': 0.3902488355835279, 'accuracy': 88.0}
# {'epoch': 25, 'batches': 100, 'elapsed_time': 90.2, 'total_loss': 0.3835050155222416, 'accuracy': 88.02}
# {'epoch': 25, 'batches': 200, 'elapsed_time': 91.6, 'total_loss': 0.38580825217068193, 'accuracy': 88.03}
# {'epoch': 25, 'batches': 300, 'elapsed_time': 92.82, 'total_loss': 0.38810822521646815, 'accuracy': 88.21}
# {'epoch': 26, 'batches': 100, 'elapsed_time': 94.44, 'total_loss': 0.38611195608973503, 'accuracy': 88.12}
# {'epoch': 26, 'batches': 200, 'elapsed_time': 95.75, 'total_loss': 0.3863731246441603, 'accuracy': 88.19}
# {'epoch': 26, 'batches': 300, 'elapsed_time': 97.11, 'total_loss': 0.3854284242292245, 'accuracy': 88.21}
# {'epoch': 27, 'batches': 100, 'elapsed_time': 98.36, 'total_loss': 0.3864943915605545, 'accuracy': 88.23}
# {'epoch': 27, 'batches': 200, 'elapsed_time': 99.79, 'total_loss': 0.3842898017168045, 'accuracy': 88.24}
# {'epoch': 27, 'batches': 300, 'elapsed_time': 100.87, 'total_loss': 0.38362658202648164, 'accuracy': 88.28}
# {'epoch': 28, 'batches': 100, 'elapsed_time': 101.94, 'total_loss': 0.3783108679950237, 'accuracy': 88.34}
# {'epoch': 28, 'batches': 200, 'elapsed_time': 102.96, 'total_loss': 0.37924888454377653, 'accuracy': 88.1}
# {'epoch': 28, 'batches': 300, 'elapsed_time': 103.97, 'total_loss': 0.381660202195247, 'accuracy': 88.53}
# {'epoch': 29, 'batches': 100, 'elapsed_time': 105.05, 'total_loss': 0.3773530113697052, 'accuracy': 88.23}
# {'epoch': 29, 'batches': 200, 'elapsed_time': 105.97, 'total_loss': 0.37792809039354325, 'accuracy': 88.33}
# {'epoch': 29, 'batches': 300, 'elapsed_time': 107.01, 'total_loss': 0.3796419643362363, 'accuracy': 88.41}
# {'epoch': 30, 'batches': 100, 'elapsed_time': 108.22, 'total_loss': 0.3853207975625992, 'accuracy': 88.4}
# {'epoch': 30, 'batches': 200, 'elapsed_time': 109.7, 'total_loss': 0.379140866547823, 'accuracy': 88.39}
# {'epoch': 30, 'batches': 300, 'elapsed_time': 111.02, 'total_loss': 0.3785926725467046, 'accuracy': 88.49}
# {'epoch': 31, 'batches': 100, 'elapsed_time': 112.39, 'total_loss': 0.3700832326710224, 'accuracy': 88.42}
# {'epoch': 31, 'batches': 200, 'elapsed_time': 113.51, 'total_loss': 0.3731980952620506, 'accuracy': 88.53}
# {'epoch': 31, 'batches': 300, 'elapsed_time': 114.66, 'total_loss': 0.37673829649885493, 'accuracy': 88.49}

# %%
def predict(inputs, w1, w2, b):
    x = inputs @ w1
    x = x * (x > 0)
    x = x @ w2 + b
    return np.argmax(x, axis=1)
    
def clip(arr, scale, bits):
    imax = 2 ** (bits - 1) - 1
    imin = -(2 ** (bits - 1))
    
    return np.clip(arr * scale, imin, imax)

# %%
data = []

weight1 = net.layer1.weight.detach().numpy().transpose()
weight2 = net.layer2.weight.detach().numpy().transpose()
bias = net.layer2.bias.detach().numpy()

for i in range(0, 32):
    SCALE = 1 << i

    w1 = clip(weight1, SCALE, 8).astype(np.int8)
    w2 = clip(weight2, SCALE, 8).astype(np.int8)
    b = clip(bias, SCALE, 8).astype(np.int8)

    pred = predict(test_inputs.numpy(), w1, w2, b)
    data.append({
        'pow': i,
        'scale': SCALE,
        'accuracy': sum(pred == test_labels.numpy()) / len(test_labels)
    })

stat = pd.DataFrame(data)
# Out:
#     pow       scale  accuracy
# 0     0           1    0.0980
# 1     1           2    0.0980
# 2     2           4    0.2776
# 3     3           8    0.7044
# 4     4          16    0.8365
# 5     5          32    0.8686
# 6     6          64    0.8819
# 7     7         128    0.8827
# 8     8         256    0.8611
# 9     9         512    0.6614
# 10   10        1024    0.5164
# 11   11        2048    0.4537
# 12   12        4096    0.4308
# 13   13        8192    0.3787
# 14   14       16384    0.3673
# 15   15       32768    0.3581
# 16   16       65536    0.3596
# 17   17      131072    0.3607
# 18   18      262144    0.3609
# 19   19      524288    0.3611
# 20   20     1048576    0.3611
# 21   21     2097152    0.3611
# 22   22     4194304    0.3611
# 23   23     8388608    0.3611
# 24   24    16777216    0.3611
# 25   25    33554432    0.3611
# 26   26    67108864    0.3611
# 27   27   134217728    0.3611
# 28   28   268435456    0.3611
# 29   29   536870912    0.3611
# 30   30  1073741824    0.3611
# 31   31  2147483648    0.3611

# %%
fig, ax = plt.subplots(figsize=(8, 5), dpi=120)
ax.scatter(stat['scale'], stat['accuracy']*100)
ax.axhline(y=85, color='orange', linestyle='dashed')
ax.set_xscale('log', base=2)
ax.set_xlabel('Scale')
ax.set_xlim(1, 2**32)
ax.set_ylabel('Accuracy (%)')
ax.set_ylim(0, 100)
fig.tight_layout()
fig.savefig("customized.pdf")
fig.savefig("customized.png")

# %%
scale = stat.set_index('scale')['accuracy'].idxmax()
w1 = clip(weight1, scale, 8).astype(np.int8)
w2 = clip(weight2, scale, 8).astype(np.int8)
b = clip(bias, scale, 8).astype(np.int8)

np.save('test_data_custom', test_inputs)
np.save('test_label_custom', test_labels)
np.save('model_weight1_custom', w1)
np.save('model_weight2_custom', w2)
np.save('model_bias_custom', b)

# %%
scale
# Out:
# 128
